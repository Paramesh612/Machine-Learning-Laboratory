# %%
import pandas as pd 
from sklearn.cluster import KMeans
# from sklearn_extra.cluster import KMedoids
import matplotlib.pyplot as plt
import numpy as np

# %%
og_data = pd.read_csv("iris dataset.csv")
k = 3  # num_clusters

# %%
data = og_data.drop('species',axis=1)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(data)
# Out:
# c:\Users\param\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1429: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
# print(kmeans.cluster_centers_)

# %%
print(len(kmeans.labels_))
# Out:
# 150

# %%
def plot_function(data,model):
    ans = model.labels_
    x= list(data[data.columns[0]])
    y= list(data[data.columns[1]])

    colorr = np.where(ans==0,'g',np.where(ans==1,'b','r'))

    for i in range(150):
        plt.scatter(x,y,c=colorr)

# %%
plot_function(data,kmeans)
